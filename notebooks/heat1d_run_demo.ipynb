# %% [markdown]
# # Project 3

# %%
import sys
from pathlib import Path

root_dir = Path.cwd().parent
sys.path.insert(0, str(root_dir))

# %%
# run_demo.py

import sys
import feelpp.core as fppc
import feelpp.toolboxes.core as tb
from feelpp.scimba.heat1d_solver import FEM_PINN_Solver

sys.argv = ["Heat1D"]
env = fppc.Environment(
    sys.argv, 
    opts=tb.toolboxes_options("coefficient-form-pdes", "cfpdes"), 
    config=fppc.localRepository("Heat1D-repo")
)

solver = FEM_PINN_Solver(xm=0.4, ω=0.8, max_iter=5, tol=1e-4, alpha=0.5)
t, u = solver.solve()
# Out:
# Using device: cpu
# [ Starting Feel++ ] application Heat1D version 0.1 date 2025-May-27
# [feelpp] create Feel++ root repository: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb
#
# [feelpp] create Feel++ geo repository: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/geo
#
# [feelpp] create Feel++ results directory: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1
#
# [feelpp] create Feel++ expressions directory: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/exprs
#
# [feelpp] create Feel++ logs directory: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/logs
#
#  . Heat1D files are stored in /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1
#  .. logfiles :/home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/logs
# >> load network /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/networks/pinn_nd.pth
# network was not loaded from file: training needed
# [Init] 🔄 Starting Neumann–Dirichlet Schwarz iterations
# Reading /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.cfg...
# [loadMesh] Loading mesh in format geo+msh: "/home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.geo"
# [loadMesh] Use default geo desc: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.geo 0.005
# [Init] FEM provided u_I(t), mean=2.516e+00
#
# === Iteration 1 ===
# epoch     0: current loss = 1.56e+01
# epoch     0: best loss = 1.56e+01
# epoch     1: best loss = 1.34e+01
# epoch     2: best loss = 1.04e+01
# epoch     3: best loss = 9.62e+00
# epoch     4: best loss = 8.49e+00
# epoch     5: best loss = 7.66e+00
# epoch     6: best loss = 7.03e+00
# epoch     7: best loss = 6.33e+00
# epoch     8: best loss = 5.95e+00
# epoch     9: best loss = 5.59e+00
# epoch    10: best loss = 5.04e+00
# epoch    11: best loss = 4.80e+00
# epoch    12: best loss = 4.48e+00
# epoch    13: best loss = 4.19e+00
# epoch    14: best loss = 3.94e+00
# epoch    15: best loss = 3.66e+00
# epoch    16: best loss = 3.33e+00
# epoch    19: best loss = 3.17e+00
# epoch    21: best loss = 2.64e+00
# epoch    22: best loss = 2.59e+00
# epoch    24: best loss = 2.10e+00
# epoch    25: best loss = 1.53e+00
# epoch    26: best loss = 1.29e+00
# epoch    33: best loss = 8.98e-01
# epoch    36: best loss = 8.11e-01
# epoch    37: best loss = 7.29e-01
# epoch    40: best loss = 5.77e-01
# epoch    43: best loss = 5.30e-01
# epoch    48: best loss = 5.09e-01
# epoch    50: best loss = 4.81e-01
# epoch    56: best loss = 4.50e-01
# epoch    60: best loss = 4.49e-01
# epoch    62: best loss = 4.45e-01
# epoch    64: best loss = 4.04e-01
# epoch    67: best loss = 3.90e-01
# epoch    68: best loss = 3.65e-01
# epoch    69: best loss = 3.57e-01
# epoch    73: best loss = 3.43e-01
# epoch    75: best loss = 3.14e-01
# epoch    76: best loss = 2.95e-01
# epoch    77: best loss = 2.90e-01
# epoch    78: best loss = 2.74e-01
# epoch    79: best loss = 2.64e-01
# epoch    80: best loss = 2.48e-01
# epoch    99: current loss = 4.66e-01
# load network: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/networks/pinn_nd.pth
# network loaded
# Reading /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.cfg...
# [loadMesh] Loading mesh in format geo+msh: "/home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.geo"
# [loadMesh] Use default geo desc: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.geo 0.005
#  Iter 1  L2 errors = [0.032829 0.564573 0.87042  1.042757 1.236404]
#  Iter 1  H1 errors = [ 0.192692 36.29713  56.77026  68.216835 81.0028  ]
#  Iter 1  Interface relative error = 3.23e-01
#
# === Iteration 2 ===
# epoch     0: current loss = 2.54e-01
# epoch     0: best loss = 2.54e-01
# epoch    66: best loss = 2.46e-01
# epoch    67: best loss = 2.45e-01
# epoch    68: best loss = 2.20e-01
# epoch    69: best loss = 2.15e-01
# epoch    72: best loss = 2.05e-01
# epoch    73: best loss = 2.02e-01
# epoch    74: best loss = 2.00e-01
# epoch    75: best loss = 1.85e-01
# epoch    79: best loss = 1.80e-01
# epoch    83: best loss = 1.78e-01
# epoch    86: best loss = 1.76e-01
# epoch    87: best loss = 1.75e-01
# epoch    88: best loss = 1.71e-01
# epoch    90: best loss = 1.71e-01
# epoch    91: best loss = 1.62e-01
# epoch    99: current loss = 1.66e-01
# load network: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/networks/pinn_nd.pth
# network loaded
# Reading /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.cfg...
# [loadMesh] Loading mesh in format geo+msh: "/home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.geo"
# [loadMesh] Use default geo desc: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.geo 0.005
#  Iter 2  L2 errors = [0.034033 0.120232 0.174224 0.205843 0.242342]
#  Iter 2  H1 errors = [ 0.198873  7.278916 11.375964 13.667364 16.227358]
#  Iter 2  Interface relative error = 1.12e-02
#
# === Iteration 3 ===
# epoch     0: current loss = 1.71e-01
# epoch     0: best loss = 1.71e-01
# epoch     2: best loss = 1.66e-01
# epoch     3: best loss = 1.63e-01
# epoch     6: best loss = 1.62e-01
# epoch     7: best loss = 1.61e-01
# epoch    10: best loss = 1.61e-01
# epoch    14: best loss = 1.58e-01
# epoch    20: best loss = 1.47e-01
# epoch    45: best loss = 1.45e-01
# epoch    46: best loss = 1.40e-01
# epoch    50: best loss = 1.38e-01
# epoch    52: best loss = 1.34e-01
# epoch    56: best loss = 1.30e-01
# epoch    59: best loss = 1.27e-01
# epoch    61: best loss = 1.26e-01
# epoch    64: best loss = 1.26e-01
# epoch    65: best loss = 1.20e-01
# epoch    66: best loss = 1.19e-01
# epoch    69: best loss = 1.19e-01
# epoch    70: best loss = 1.12e-01
# epoch    72: best loss = 1.11e-01
# epoch    75: best loss = 1.07e-01
# epoch    76: best loss = 1.00e-01
# epoch    81: best loss = 9.30e-02
# epoch    82: best loss = 9.21e-02
# epoch    86: best loss = 9.13e-02
# epoch    87: best loss = 8.68e-02
# epoch    88: best loss = 8.51e-02
# epoch    89: best loss = 8.11e-02
# epoch    90: best loss = 7.80e-02
# epoch    94: best loss = 7.57e-02
# epoch    96: best loss = 7.09e-02
# epoch    99: best loss = 6.42e-02
# epoch    99: current loss = 6.42e-02
# load network: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/networks/pinn_nd.pth
# network loaded
# Reading /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.cfg...
# [loadMesh] Loading mesh in format geo+msh: "/home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.geo"
# [loadMesh] Use default geo desc: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.geo 0.005
#  Iter 3  L2 errors = [0.037232 0.038724 0.045068 0.050375 0.057602]
#  Iter 3  H1 errors = [0.214588 1.497244 2.316514 2.776376 3.290981]
#  Iter 3  Interface relative error = 7.78e-02
#
# === Iteration 4 ===
# epoch     0: current loss = 6.69e-02
# epoch     0: best loss = 6.69e-02
# epoch     1: best loss = 6.48e-02
# epoch     3: best loss = 6.30e-02
# epoch     4: best loss = 6.29e-02
# epoch     8: best loss = 6.15e-02
# epoch     9: best loss = 5.55e-02
# epoch    11: best loss = 5.49e-02
# epoch    14: best loss = 5.19e-02
# epoch    22: best loss = 4.75e-02
# epoch    24: best loss = 4.69e-02
# epoch    25: best loss = 4.51e-02
# epoch    46: best loss = 4.07e-02
# epoch    51: best loss = 3.61e-02
# epoch    56: best loss = 3.50e-02
# epoch    61: best loss = 3.39e-02
# epoch    66: best loss = 3.23e-02
# epoch    67: best loss = 2.99e-02
# epoch    72: best loss = 2.64e-02
# epoch    79: best loss = 2.57e-02
# epoch    80: best loss = 2.41e-02
# epoch    90: best loss = 2.41e-02
# epoch    91: best loss = 2.22e-02
# epoch    92: best loss = 1.75e-02
# epoch    96: best loss = 1.68e-02
# epoch    97: best loss = 1.65e-02
# epoch    99: current loss = 1.89e-02
# load network: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/networks/pinn_nd.pth
# network loaded
# Reading /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.cfg...
# [loadMesh] Loading mesh in format geo+msh: "/home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.geo"
# [loadMesh] Use default geo desc: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.geo 0.005
#  Iter 4  L2 errors = [0.039101 0.02794  0.030861 0.03485  0.04044 ]
#  Iter 4  H1 errors = [0.224532 0.426816 0.586963 0.680077 0.786013]
#  Iter 4  Interface relative error = 9.12e-02
#
# === Iteration 5 ===
# epoch     0: current loss = 1.67e-02
# epoch     0: best loss = 1.67e-02
# epoch    21: best loss = 1.38e-02
# epoch    25: best loss = 1.37e-02
# epoch    29: best loss = 1.15e-02
# epoch    33: best loss = 1.15e-02
# epoch    37: best loss = 1.08e-02
# epoch    40: best loss = 1.04e-02
# epoch    41: best loss = 1.02e-02
# epoch    45: best loss = 9.05e-03
# epoch    61: best loss = 9.00e-03
# epoch    65: best loss = 8.73e-03
# epoch    72: best loss = 8.68e-03
# epoch    75: best loss = 8.49e-03
# epoch    76: best loss = 8.41e-03
# epoch    80: best loss = 8.13e-03
# epoch    96: best loss = 7.99e-03
# epoch    99: current loss = 8.71e-03
# load network: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/networks/pinn_nd.pth
# network loaded
# Reading /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.cfg...
# [loadMesh] Loading mesh in format geo+msh: "/home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.geo"
# [loadMesh] Use default geo desc: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/Heat1D-repo/np_1/fem.geo 0.005
#  Iter 5  L2 errors = [0.039684 0.026703 0.03029  0.034808 0.040855]
#  Iter 5  H1 errors = [0.22761  0.306898 0.363419 0.395753 0.432562]
#  Iter 5  Interface relative error = 9.39e-02
# ⚠️ Reached max_iter without meeting tolerance.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
alpha = 0.5
times = [0.0, 0.006, 0.014, 0.020, 0.028]
x = np.linspace(0, 1, 500)

plt.figure(figsize=(8, 4))
for t in times:
    u_exact = np.exp(-alpha * np.pi**2 * t) * np.sin(np.pi * x)
    plt.plot(x, u_exact, label=f"t={t:.3f}")

plt.xlabel("x")
plt.ylabel("u_exact")
plt.title("Exact Solution at Selected Times")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
