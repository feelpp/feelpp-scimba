# %% [markdown]
# # Project 3

# %%
import sys
from pathlib import Path

root_dir = Path.cwd().parent
sys.path.insert(0, str(root_dir))

# %%
# run_demo.py

import sys
import feelpp.core as fppc
import feelpp.toolboxes.core as tb
from feelpp.scimba.heat1d_solver import FEM_PINN_Solver

sys.argv = ["feelpp_fem"]
env = fppc.Environment(
    sys.argv, 
    opts=tb.toolboxes_options("coefficient-form-pdes", "cfpdes"), 
    config=fppc.localRepository("fem-repo")
)

solver = FEM_PINN_Solver(xm=0.4, ω=0.8, max_iter=5, tol=1e-4, alpha=0.5)
t, u = solver.solve()
# Out:
# Using device: cpu
# [ Starting Feel++ ] application feelpp_fem version 0.1 date 2025-May-27
# [feelpp] create Feel++ root repository: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb
#
# [feelpp] create Feel++ geo repository: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/geo
#
# [feelpp] create Feel++ results directory: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1
#
# [feelpp] create Feel++ expressions directory: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/exprs
#
# [feelpp] create Feel++ logs directory: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/logs
#
#  . feelpp_fem files are stored in /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1
#  .. logfiles :/home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/logs
# >> load network /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/networks/pinn_nd.pth
# network was not loaded from file: training needed
# [Init] 🔄 Starting Neumann–Dirichlet Schwarz iterations
# Reading /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.cfg...
# [loadMesh] Loading mesh in format geo+msh: "/home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.geo"
# [loadMesh] Use default geo desc: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.geo 0.005
# [Init] FEM provided u_I(t), mean=2.516e+00
#
# === Iteration 1 ===
# epoch     0: current loss = 1.55e+01
# epoch     0: best loss = 1.55e+01
# epoch     1: best loss = 1.27e+01
# epoch     2: best loss = 8.72e+00
# epoch     3: best loss = 6.79e+00
# epoch     4: best loss = 5.95e+00
# epoch     5: best loss = 5.07e+00
# epoch     7: best loss = 4.38e+00
# epoch     8: best loss = 4.18e+00
# epoch    10: best loss = 3.71e+00
# epoch    12: best loss = 3.44e+00
# epoch    13: best loss = 3.11e+00
# epoch    14: best loss = 2.46e+00
# epoch    15: best loss = 1.89e+00
# epoch    21: best loss = 1.66e+00
# epoch    22: best loss = 1.09e+00
# epoch    23: best loss = 8.13e-01
# epoch    35: best loss = 8.13e-01
# epoch    42: best loss = 7.48e-01
# epoch    49: best loss = 6.76e-01
# epoch    50: best loss = 6.33e-01
# epoch    51: best loss = 5.47e-01
# epoch    58: best loss = 5.35e-01
# epoch    59: best loss = 5.25e-01
# epoch    60: best loss = 5.03e-01
# epoch    67: best loss = 4.98e-01
# epoch    68: best loss = 4.92e-01
# epoch    69: best loss = 4.85e-01
# epoch    75: best loss = 4.75e-01
# epoch    76: best loss = 4.61e-01
# epoch    77: best loss = 4.51e-01
# epoch    83: best loss = 4.44e-01
# epoch    86: best loss = 4.42e-01
# epoch    87: best loss = 3.99e-01
# epoch    90: best loss = 3.96e-01
# epoch    91: best loss = 3.66e-01
# epoch    93: best loss = 3.60e-01
# epoch    95: best loss = 3.37e-01
# epoch    96: best loss = 3.29e-01
# epoch    97: best loss = 2.99e-01
# epoch    98: best loss = 2.91e-01
# epoch    99: best loss = 2.78e-01
# epoch    99: current loss = 2.78e-01
# load network: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/networks/pinn_nd.pth
# network loaded
# Reading /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.cfg...
# [loadMesh] Loading mesh in format geo+msh: "/home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.geo"
# [loadMesh] Use default geo desc: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.geo 0.005
#  Iter 1  L2 errors = [0.031325 0.563428 0.869358 1.041756 1.235484]
#  Iter 1  H1 errors = [ 0.185664 36.297054 56.7702   68.21678  81.00274 ]
#  Iter 1  Interface relative error = 3.23e-01
#
# === Iteration 2 ===
# epoch     0: current loss = 2.50e-01
# epoch     0: best loss = 2.50e-01
# epoch     1: best loss = 2.39e-01
# epoch     2: best loss = 2.18e-01
# epoch     3: best loss = 2.03e-01
# epoch     4: best loss = 1.98e-01
# epoch    68: best loss = 1.98e-01
# epoch    69: best loss = 1.97e-01
# epoch    73: best loss = 1.95e-01
# epoch    77: best loss = 1.92e-01
# epoch    78: best loss = 1.89e-01
# epoch    79: best loss = 1.87e-01
# epoch    80: best loss = 1.80e-01
# epoch    83: best loss = 1.74e-01
# epoch    85: best loss = 1.74e-01
# epoch    87: best loss = 1.73e-01
# epoch    88: best loss = 1.69e-01
# epoch    90: best loss = 1.65e-01
# epoch    91: best loss = 1.64e-01
# epoch    92: best loss = 1.63e-01
# epoch    99: best loss = 1.55e-01
# epoch    99: current loss = 1.55e-01
# load network: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/networks/pinn_nd.pth
# network loaded
# Reading /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.cfg...
# [loadMesh] Loading mesh in format geo+msh: "/home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.geo"
# [loadMesh] Use default geo desc: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.geo 0.005
#  Iter 2  L2 errors = [0.034193 0.120382 0.174391 0.206027 0.242548]
#  Iter 2  H1 errors = [ 0.199581  7.278944 11.375989 13.667389 16.227385]
#  Iter 2  Interface relative error = 1.12e-02
#
# === Iteration 3 ===
# epoch     0: current loss = 1.55e-01
# epoch     0: best loss = 1.55e-01
# epoch     3: best loss = 1.53e-01
# epoch     8: best loss = 1.51e-01
# epoch     9: best loss = 1.51e-01
# epoch    10: best loss = 1.50e-01
# epoch    13: best loss = 1.45e-01
# epoch    24: best loss = 1.45e-01
# epoch    26: best loss = 1.39e-01
# epoch    37: best loss = 1.33e-01
# epoch    44: best loss = 1.27e-01
# epoch    46: best loss = 1.24e-01
# epoch    50: best loss = 1.23e-01
# epoch    51: best loss = 1.19e-01
# epoch    53: best loss = 1.18e-01
# epoch    54: best loss = 1.15e-01
# epoch    59: best loss = 1.12e-01
# epoch    61: best loss = 1.09e-01
# epoch    62: best loss = 1.07e-01
# epoch    66: best loss = 1.04e-01
# epoch    67: best loss = 1.03e-01
# epoch    69: best loss = 9.82e-02
# epoch    72: best loss = 9.80e-02
# epoch    73: best loss = 9.77e-02
# epoch    74: best loss = 9.65e-02
# epoch    75: best loss = 9.08e-02
# epoch    78: best loss = 8.88e-02
# epoch    80: best loss = 8.84e-02
# epoch    81: best loss = 8.64e-02
# epoch    84: best loss = 8.23e-02
# epoch    86: best loss = 8.16e-02
# epoch    89: best loss = 8.12e-02
# epoch    91: best loss = 7.74e-02
# epoch    93: best loss = 7.64e-02
# epoch    94: best loss = 7.56e-02
# epoch    96: best loss = 7.37e-02
# epoch    99: best loss = 7.34e-02
# epoch    99: current loss = 7.34e-02
# load network: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/networks/pinn_nd.pth
# network loaded
# Reading /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.cfg...
# [loadMesh] Loading mesh in format geo+msh: "/home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.geo"
# [loadMesh] Use default geo desc: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.geo 0.005
#  Iter 3  L2 errors = [0.037664 0.0391   0.045373 0.050635 0.057805]
#  Iter 3  H1 errors = [0.21662  1.497534 2.316694 2.776518 3.291084]
#  Iter 3  Interface relative error = 7.78e-02
#
# === Iteration 4 ===
# epoch     0: current loss = 7.50e-02
# epoch     0: best loss = 7.50e-02
# epoch     1: best loss = 7.47e-02
# epoch     2: best loss = 7.26e-02
# epoch     3: best loss = 7.14e-02
# epoch     5: best loss = 6.90e-02
# epoch     8: best loss = 6.81e-02
# epoch    12: best loss = 6.63e-02
# epoch    17: best loss = 6.54e-02
# epoch    21: best loss = 6.54e-02
# epoch    22: best loss = 6.22e-02
# epoch    26: best loss = 6.15e-02
# epoch    29: best loss = 6.12e-02
# epoch    33: best loss = 6.01e-02
# epoch    36: best loss = 5.76e-02
# epoch    40: best loss = 5.69e-02
# epoch    48: best loss = 5.62e-02
# epoch    49: best loss = 5.61e-02
# epoch    53: best loss = 5.53e-02
# epoch    54: best loss = 5.35e-02
# epoch    59: best loss = 5.32e-02
# epoch    61: best loss = 5.31e-02
# epoch    62: best loss = 5.12e-02
# epoch    64: best loss = 5.02e-02
# epoch    68: best loss = 4.88e-02
# epoch    71: best loss = 4.87e-02
# epoch    75: best loss = 4.52e-02
# epoch    82: best loss = 4.43e-02
# epoch    83: best loss = 4.29e-02
# epoch    84: best loss = 4.07e-02
# epoch    91: best loss = 4.06e-02
# epoch    94: best loss = 4.04e-02
# epoch    98: best loss = 3.75e-02
# epoch    99: current loss = 3.78e-02
# load network: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/networks/pinn_nd.pth
# network loaded
# Reading /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.cfg...
# [loadMesh] Loading mesh in format geo+msh: "/home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.geo"
# [loadMesh] Use default geo desc: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.geo 0.005
#  Iter 4  L2 errors = [0.038407 0.027353 0.030473 0.034555 0.040207]
#  Iter 4  H1 errors = [0.220752 0.424926 0.585682 0.679026 0.785123]
#  Iter 4  Interface relative error = 9.12e-02
#
# === Iteration 5 ===
# epoch     0: current loss = 3.97e-02
# epoch     0: best loss = 3.97e-02
# epoch     1: best loss = 3.52e-02
# epoch     4: best loss = 3.48e-02
# epoch     6: best loss = 3.29e-02
# epoch     8: best loss = 3.28e-02
# epoch     9: best loss = 3.14e-02
# epoch    11: best loss = 2.98e-02
# epoch    14: best loss = 2.98e-02
# epoch    15: best loss = 2.96e-02
# epoch    16: best loss = 2.71e-02
# epoch    20: best loss = 2.71e-02
# epoch    21: best loss = 2.64e-02
# epoch    23: best loss = 2.63e-02
# epoch    24: best loss = 2.45e-02
# epoch    26: best loss = 2.38e-02
# epoch    27: best loss = 2.37e-02
# epoch    28: best loss = 2.19e-02
# epoch    33: best loss = 2.11e-02
# epoch    35: best loss = 1.96e-02
# epoch    36: best loss = 1.96e-02
# epoch    38: best loss = 1.93e-02
# epoch    40: best loss = 1.89e-02
# epoch    43: best loss = 1.69e-02
# epoch    44: best loss = 1.66e-02
# epoch    45: best loss = 1.64e-02
# epoch    47: best loss = 1.54e-02
# epoch    50: best loss = 1.48e-02
# epoch    56: best loss = 1.45e-02
# epoch    57: best loss = 1.41e-02
# epoch    58: best loss = 1.36e-02
# epoch    59: best loss = 1.35e-02
# epoch    60: best loss = 1.31e-02
# epoch    64: best loss = 1.30e-02
# epoch    65: best loss = 1.24e-02
# epoch    77: best loss = 1.18e-02
# epoch    83: best loss = 1.16e-02
# epoch    88: best loss = 1.12e-02
# epoch    96: best loss = 1.02e-02
# epoch    99: current loss = 1.51e-02
# load network: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/networks/pinn_nd.pth
# network loaded
# Reading /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.cfg...
# [loadMesh] Loading mesh in format geo+msh: "/home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.geo"
# [loadMesh] Use default geo desc: /home/u4/csmi/2024/he/feelpp-scimba/notebooks/feelppdb/fem-repo/np_1/fem.geo 0.005
#  Iter 5  L2 errors = [0.039567 0.026582 0.030219 0.034764 0.040826]
#  Iter 5  H1 errors = [0.22697  0.306361 0.362999 0.395419 0.432274]
#  Iter 5  Interface relative error = 9.39e-02
# ⚠️ Reached max_iter without meeting tolerance.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Parameters
alpha = 0.5
times = [0.0, 0.006, 0.014, 0.020, 0.028]
x = np.linspace(0, 1, 500)

plt.figure(figsize=(8, 4))
for t in times:
    u_exact = np.exp(-alpha * np.pi**2 * t) * np.sin(np.pi * x)
    plt.plot(x, u_exact, label=f"t={t:.3f}")

plt.xlabel("x")
plt.ylabel("u_exact")
plt.title("Exact Solution at Selected Times")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.show()
